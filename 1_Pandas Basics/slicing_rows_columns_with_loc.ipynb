# %%
import pandas as pd

# %%
#setting index to Athlete column
summer = pd.read_csv('summer.csv',index_col = 'Athlete')
summer.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer.loc['PHELPS, Michael']
# Out:
#                  Year     City     Sport Discipline Country Gender  \
# Athlete
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# ...

# %%
#slice index and column
summer.loc['PHELPS, Michael', ['Year']]
# Out:
#                  Year
# Athlete
# PHELPS, Michael  2004
# PHELPS, Michael  2004
# PHELPS, Michael  2004
# PHELPS, Michael  2004
# PHELPS, Michael  2004
# PHELPS, Michael  2004
# PHELPS, Michael  2004
# PHELPS, Michael  2004
# PHELPS, Michael  2008
# PHELPS, Michael  2008
# PHELPS, Michael  2008
# PHELPS, Michael  2008
# PHELPS, Michael  2008
# PHELPS, Michael  2008
# PHELPS, Michael  2008
# PHELPS, Michael  2008
# PHELPS, Michael  2012
# PHELPS, Michael  2012
# PHELPS, Michael  2012
# PHELPS, Michael  2012
# PHELPS, Michael  2012
# PHELPS, Michael  2012

# %%
summer.loc['PHELPS, Michael', ['Year','Medal','Event']]
# Out:
#                  Year   Medal                   Event
# Athlete
# PHELPS, Michael  2004    Gold          100M Butterfly
# PHELPS, Michael  2004    Gold          200M Butterfly
# PHELPS, Michael  2004  Bronze          200M Freestyle
# PHELPS, Michael  2004    Gold  200M Individual Medley
# PHELPS, Michael  2004    Gold  400M Individual Medley
# PHELPS, Michael  2004  Bronze  4X100M Freestyle Relay
# PHELPS, Michael  2004    Gold     4X100M Medley Relay
# PHELPS, Michael  2004    Gold  4X200M Freestyle Relay
# PHELPS, Michael  2008    Gold          100M Butterfly
# PHELPS, Michael  2008    Gold          200M Butterfly
# PHELPS, Michael  2008    Gold          200M Freestyle
# PHELPS, Michael  2008    Gold  200M Individual Medley
# PHELPS, Michael  2008    Gold  400M Individual Medley
# PHELPS, Michael  2008    Gold  4X100M Freestyle Relay
# PHELPS, Michael  2008    Gold     4X100M Medley Relay
# PHELPS, Michael  2008    Gold  4X200M Freestyle Relay
# ...

# %%
summer.loc[['PHELPS, Michael','LEWIS, Carl'], ['Year','Medal','Event']]
# Out:
#                  Year   Medal                   Event
# Athlete
# PHELPS, Michael  2004    Gold          100M Butterfly
# PHELPS, Michael  2004    Gold          200M Butterfly
# PHELPS, Michael  2004  Bronze          200M Freestyle
# PHELPS, Michael  2004    Gold  200M Individual Medley
# PHELPS, Michael  2004    Gold  400M Individual Medley
# PHELPS, Michael  2004  Bronze  4X100M Freestyle Relay
# PHELPS, Michael  2004    Gold     4X100M Medley Relay
# PHELPS, Michael  2004    Gold  4X200M Freestyle Relay
# PHELPS, Michael  2008    Gold          100M Butterfly
# PHELPS, Michael  2008    Gold          200M Butterfly
# PHELPS, Michael  2008    Gold          200M Freestyle
# PHELPS, Michael  2008    Gold  200M Individual Medley
# PHELPS, Michael  2008    Gold  400M Individual Medley
# PHELPS, Michael  2008    Gold  4X100M Freestyle Relay
# PHELPS, Michael  2008    Gold     4X100M Medley Relay
# PHELPS, Michael  2008    Gold  4X200M Freestyle Relay
# ...

# %%
summer.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %% [markdown]
# ## End point is included in Location based indexing

# %%
summer.loc[:'CHASAPIS, Spiridon']
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %% [markdown]
# ## Slicing using loc doesn't work for non-unique values

# %%
summer.loc[:'PHELPS, Michael']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-b258374d48a1> in <module>
# ----> 1 summer.loc[:'PHELPS, Michael']
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1795         if isinstance(key, slice):
#    1796             self._validate_key(key, axis)
# -> 1797             return self._get_slice_axis(key, axis=axis)
#    1798         elif com.is_bool_indexer(key):
#    1799             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
summer.loc['HAJOS, Alfred':]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-1a51f1bfbe6b> in <module>
# ----> 1 summer.loc['HAJOS, Alfred':]
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1795         if isinstance(key, slice):
#    1796             self._validate_key(key, axis)
# -> 1797             return self._get_slice_axis(key, axis=axis)
#    1798         elif com.is_bool_indexer(key):
#    1799             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
summer.head(20)
# Out:
#                        Year    City      Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens   Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens   Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens   Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens   Aquatics   Swimming     AUT    Men
# PEPANOS, Antonios      1896  Athens   Aquatics   Swimming     GRE    Men
# LANE, Francis          1896  Athens  Athletics  Athletics     USA    Men
# ...

# %%
summer.loc['DRIVAS, Dimitrios': 'BLAKE, Arthur'] #start and end points included
# Out:
#                        Year    City      Sport Discipline Country Gender  \
# Athlete
# DRIVAS, Dimitrios      1896  Athens   Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens   Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens   Aquatics   Swimming     AUT    Men
# PEPANOS, Antonios      1896  Athens   Aquatics   Swimming     GRE    Men
# LANE, Francis          1896  Athens  Athletics  Athletics     USA    Men
# SZOKOLYI, Alajos       1896  Athens  Athletics  Athletics     HUN    Men
# BURKE, Thomas          1896  Athens  Athletics  Athletics     USA    Men
# ...

# %%
summer.loc['DRIVAS, Dimitrios','Year':'Country']
# Out:
# Year              1896
# City            Athens
# Sport         Aquatics
# Discipline    Swimming
# Country            GRE
# Name: DRIVAS, Dimitrios, dtype: object

# %%
summer.loc[['PHELPS, Michael','DUCK, Donald']]
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                    Year     City     Sport Discipline Country Gender  \
# Athlete
# PHELPS, Michael  2004.0   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004.0   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004.0   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004.0   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004.0   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004.0   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004.0   Athens  Aquatics   Swimming     USA    Men
# ...

# %%
summer.loc['PHELPS, Michael',['Year','Age']]
# Out:
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                  Year  Age
# Athlete
# PHELPS, Michael  2004  NaN
# PHELPS, Michael  2004  NaN
# PHELPS, Michael  2004  NaN
# PHELPS, Michael  2004  NaN
# PHELPS, Michael  2004  NaN
# PHELPS, Michael  2004  NaN
# PHELPS, Michael  2004  NaN
# PHELPS, Michael  2004  NaN
# PHELPS, Michael  2008  NaN
# PHELPS, Michael  2008  NaN
# PHELPS, Michael  2008  NaN
# PHELPS, Michael  2008  NaN
# PHELPS, Michael  2008  NaN
# PHELPS, Michael  2008  NaN
# PHELPS, Michael  2008  NaN
# PHELPS, Michael  2008  NaN
# PHELPS, Michael  2012  NaN
# PHELPS, Michael  2012  NaN
# PHELPS, Michael  2012  NaN
# ...
