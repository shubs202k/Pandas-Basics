# %%
import pandas as pd
summer = pd.read_csv('summer.csv',index_col = 'Athlete')
summer.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %% [markdown]
# ## Index opertor loc (label based indexing)

# %% [markdown]
# ## Select rows with loc

# %%
summer.iloc[2] #athlete column not included
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
summer.loc['DRIVAS, Dimitrios']
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
summer.loc['PHELPS, Michael']
# Out:
#                  Year     City     Sport Discipline Country Gender  \
# Athlete
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# ...

# %%
summer.loc['PHELPS, Michael'].iloc[0] #first medal for phelps
# Out:
# Year                    2004
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  USA
# Gender                   Men
# Event         100M Butterfly
# Medal                   Gold
# Name: PHELPS, Michael, dtype: object

# %%
summer.loc['BOLT, Usain']
# Out:
#              Year     City      Sport Discipline Country Gender         Event  \
# Athlete
# BOLT, Usain  2008  Beijing  Athletics  Athletics     JAM    Men          100M
# BOLT, Usain  2008  Beijing  Athletics  Athletics     JAM    Men          200M
# BOLT, Usain  2008  Beijing  Athletics  Athletics     JAM    Men  4X100M Relay
# BOLT, Usain  2012   London  Athletics  Athletics     JAM    Men          100M
# BOLT, Usain  2012   London  Athletics  Athletics     JAM    Men          200M
# BOLT, Usain  2012   London  Athletics  Athletics     JAM    Men  4X100M Relay
#
#             Medal
# Athlete
# BOLT, Usain  Gold
# BOLT, Usain  Gold
# BOLT, Usain  Gold
# BOLT, Usain  Gold
# BOLT, Usain  Gold
# BOLT, Usain  Gold

# %%
summer.loc['MURRAY, Andy']
# Out:
#               Year    City   Sport Discipline Country Gender          Event  \
# Athlete
# MURRAY, Andy  2012  London  Tennis     Tennis     GBR    Men  Mixed Doubles
# MURRAY, Andy  2012  London  Tennis     Tennis     GBR    Men        Singles
#
#                Medal
# Athlete
# MURRAY, Andy  Silver
# MURRAY, Andy    Gold

# %%
summer.loc['BINDRA, Abhinav'] #no datframe for a single entry
# Out:
# Year                              2008
# City                           Beijing
# Sport                         Shooting
# Discipline                    Shooting
# Country                            IND
# Gender                             Men
# Event         10M Air Rifle (60 Shots)
# Medal                             Gold
# Name: BINDRA, Abhinav, dtype: object
