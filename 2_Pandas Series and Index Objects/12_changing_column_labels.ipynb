# %%
import pandas as pd
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %%
titanic.columns[0]
# Out:
# 'survived'

# %%
titanic.columns[0] = 'alive'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-8eb275469701> in <module>
# ----> 1 titanic.columns[0] = 'alive'
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    4258
#    4259     def __setitem__(self, key, value):
# -> 4260         raise TypeError("Index does not support mutable operations")
#    4261
#    4262     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
#to change name of a column pass a list with all column names
titanic.columns = ['alive', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'deck']

# %%
titanic.head()
# Out:
#    alive  pclass     sex   age  sibsp  parch     fare embarked deck
# 0      0       3    male  22.0      1      0   7.2500        S  NaN
# 1      1       1  female  38.0      1      0  71.2833        C    C
# 2      1       3  female  26.0      0      0   7.9250        S  NaN
# 3      1       1  female  35.0      1      0  53.1000        S    C
# 4      0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.columns.name

# %%
titanic.columns.name = 'Passenger Characteristics'

# %%
titanic.head()
# Out:
# Passenger Characteristics  alive  pclass     sex   age  sibsp  parch     fare  \
# 0                              0       3    male  22.0      1      0   7.2500
# 1                              1       1  female  38.0      1      0  71.2833
# 2                              1       3  female  26.0      0      0   7.9250
# 3                              1       1  female  35.0      1      0  53.1000
# 4                              0       3    male  35.0      0      0   8.0500
#
# Passenger Characteristics embarked deck
# 0                                S  NaN
# 1                                C    C
# 2                                S  NaN
# 3                                S    C
# 4                                S  NaN

# %%
titanic.index.name = 'Indexes'

# %%
titanic.head()
# Out:
# Passenger Characteristics  alive  pclass     sex   age  sibsp  parch     fare  \
# Indexes
# 0                              0       3    male  22.0      1      0   7.2500
# 1                              1       1  female  38.0      1      0  71.2833
# 2                              1       3  female  26.0      0      0   7.9250
# 3                              1       1  female  35.0      1      0  53.1000
# 4                              0       3    male  35.0      0      0   8.0500
#
# Passenger Characteristics embarked deck
# Indexes
# 0                                S  NaN
# 1                                C    C
# 2                                S  NaN
# 3                                S    C
# 4                                S  NaN
