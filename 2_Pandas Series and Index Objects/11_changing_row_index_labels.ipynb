# %%
import pandas as pd
summer = pd.read_csv('summer.csv', index_col = 'Athlete')
summer.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %% [markdown]
# ## Changing row index labels

# %%
summer.index
# Out:
# Index(['HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios',
#        'MALOKINIS, Ioannis', 'CHASAPIS, Spiridon', 'CHOROPHAS, Efstathios',
#        'HAJOS, Alfred', 'ANDREOU, Joannis', 'CHOROPHAS, Efstathios',
#        'NEUMANN, Paul',
#        ...
#        'AHMADOV, Emin', 'KAZAKEVIC, Aleksandr', 'KHUGAEV, Alan',
#        'EBRAHIM, Karam Mohamed Gaber', 'GAJIYEV, Danyal', 'JANIKOWSKI, Damian',
#        'REZAEI, Ghasem Gholamreza', 'TOTROV, Rustam', 'ALEKSANYAN, Artur',
#        'LIDBERG, Jimmy'],
#       dtype='object', name='Athlete', length=31165)

# %%
#change it back to range index
#summer.reset_index(drop = True) # drop index we had before

summer.reset_index(drop = False, inplace = True)

# %%
summer.head()
# Out:
#               Athlete  Year    City     Sport Discipline Country Gender  \
# 0       HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
# 1    HERSCHMANN, Otto  1896  Athens  Aquatics   Swimming     AUT    Men
# 2   DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
# 3  MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# 4  CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.set_index('Year', drop = True, inplace = True) #set a different index

# %%
summer.head()
# Out:
#                  Athlete    City     Sport Discipline Country Gender  \
# Year
# 1896       HAJOS, Alfred  Athens  Aquatics   Swimming     HUN    Men
# 1896    HERSCHMANN, Otto  Athens  Aquatics   Swimming     AUT    Men
# 1896   DRIVAS, Dimitrios  Athens  Aquatics   Swimming     GRE    Men
# 1896  MALOKINIS, Ioannis  Athens  Aquatics   Swimming     GRE    Men
# 1896  CHASAPIS, Spiridon  Athens  Aquatics   Swimming     GRE    Men
#
#                            Event   Medal
# Year
# 1896              100M Freestyle    Gold
# 1896              100M Freestyle  Silver
# 1896  100M Freestyle For Sailors  Bronze
# 1896  100M Freestyle For Sailors    Gold
# 1896  100M Freestyle For Sailors  Silver

# %%
summer.index.is_unique
# Out:
# False

# %% [markdown]
# ## Change one element of the index

# %%
summer.index[0] = 1894
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-730706281fbe> in <module>
# ----> 1 summer.index[0] = 1894
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    4258
#    4259     def __setitem__(self, key, value):
# -> 4260         raise TypeError("Index does not support mutable operations")
#    4261
#    4262     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
summer.index = 'Before 2016'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-4ce3c2bdf743> in <module>
# ----> 1 summer.index = 'Before 2016'
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5190         try:
#    5191             object.__getattribute__(self, name)
# -> 5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#    5194             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     688
#     689     def _set_axis(self, axis, labels):
# --> 690         self._data.set_axis(axis, labels)
#     691         self._clear_item_cache()
#     692
#
# ...

# %%
summer.index.size
# Out:
# 31165

# %%
new_index = ['Medal No {}'.format(i) for i in range(1,summer.index.size+1)]
new_index
# Out:
# ['Medal No 1',
#  'Medal No 2',
#  'Medal No 3',
#  'Medal No 4',
#  'Medal No 5',
#  'Medal No 6',
#  'Medal No 7',
#  'Medal No 8',
#  'Medal No 9',
#  'Medal No 10',
#  'Medal No 11',
#  'Medal No 12',
#  'Medal No 13',
#  'Medal No 14',
#  'Medal No 15',
#  'Medal No 16',
#  'Medal No 17',
#  'Medal No 18',
#  'Medal No 19',
#  'Medal No 20',
#  'Medal No 21',
#  'Medal No 22',
#  'Medal No 23',
#  'Medal No 24',
#  'Medal No 25',
#  'Medal No 26',
#  'Medal No 27',
#  'Medal No 28',
#  'Medal No 29',
#  'Medal No 30',
#  'Medal No 31',
#  'Medal No 32',
#  'Medal No 33',
#  'Medal No 34',
#  'Medal No 35',
#  'Medal No 36',
#  'Medal No 37',
#  'Medal No 38',
#  'Medal No 39',
#  'Medal No 40',
#  'Medal No 41',
#  'Medal No 42',
#  'Medal No 43',
#  'Medal No 44',
#  'Medal No 45',
#  'Medal No 46',
#  'Medal No 47',
#  'Medal No 48',
#  'Medal No 49',
#  'Medal No 50',
#  'Medal No 51',
#  'Medal No 52',
#  'Medal No 53',
#  'Medal No 54',
#  'Medal No 55',
#  'Medal No 56',
# ...

# %%
summer.index = new_index

# %%
summer.head() #old index not present
# Out:
#                        Athlete    City     Sport Discipline Country Gender  \
# Medal No 1       HAJOS, Alfred  Athens  Aquatics   Swimming     HUN    Men
# Medal No 2    HERSCHMANN, Otto  Athens  Aquatics   Swimming     AUT    Men
# Medal No 3   DRIVAS, Dimitrios  Athens  Aquatics   Swimming     GRE    Men
# Medal No 4  MALOKINIS, Ioannis  Athens  Aquatics   Swimming     GRE    Men
# Medal No 5  CHASAPIS, Spiridon  Athens  Aquatics   Swimming     GRE    Men
#
#                                  Event   Medal
# Medal No 1              100M Freestyle    Gold
# Medal No 2              100M Freestyle  Silver
# Medal No 3  100M Freestyle For Sailors  Bronze
# Medal No 4  100M Freestyle For Sailors    Gold
# Medal No 5  100M Freestyle For Sailors  Silver

# %%
summer.tail()
# Out:
#                                   Athlete    City      Sport  \
# Medal No 31161         JANIKOWSKI, Damian  London  Wrestling
# Medal No 31162  REZAEI, Ghasem Gholamreza  London  Wrestling
# Medal No 31163             TOTROV, Rustam  London  Wrestling
# Medal No 31164          ALEKSANYAN, Artur  London  Wrestling
# Medal No 31165             LIDBERG, Jimmy  London  Wrestling
#
#                          Discipline Country Gender     Event   Medal
# Medal No 31161  Wrestling Freestyle     POL    Men  Wg 84 KG  Bronze
# Medal No 31162  Wrestling Freestyle     IRI    Men  Wg 96 KG    Gold
# Medal No 31163  Wrestling Freestyle     RUS    Men  Wg 96 KG  Silver
# Medal No 31164  Wrestling Freestyle     ARM    Men  Wg 96 KG  Bronze
# Medal No 31165  Wrestling Freestyle     SWE    Men  Wg 96 KG  Bronze

# %%
summer.index.is_unique
# Out:
# True

# %%
summer.index.name

# %%
summer.index.name = 'Medal No'

# %%
summer.head()
# Out:
#                        Athlete    City     Sport Discipline Country Gender  \
# Medal No
# Medal No 1       HAJOS, Alfred  Athens  Aquatics   Swimming     HUN    Men
# Medal No 2    HERSCHMANN, Otto  Athens  Aquatics   Swimming     AUT    Men
# Medal No 3   DRIVAS, Dimitrios  Athens  Aquatics   Swimming     GRE    Men
# Medal No 4  MALOKINIS, Ioannis  Athens  Aquatics   Swimming     GRE    Men
# Medal No 5  CHASAPIS, Spiridon  Athens  Aquatics   Swimming     GRE    Men
#
#                                  Event   Medal
# Medal No
# Medal No 1              100M Freestyle    Gold
# Medal No 2              100M Freestyle  Silver
# Medal No 3  100M Freestyle For Sailors  Bronze
# Medal No 4  100M Freestyle For Sailors    Gold
# Medal No 5  100M Freestyle For Sailors  Silver

# %%
summer.reset_index()
# Out:
#              Medal No                    Athlete    City      Sport  \
# 0          Medal No 1              HAJOS, Alfred  Athens   Aquatics
# 1          Medal No 2           HERSCHMANN, Otto  Athens   Aquatics
# 2          Medal No 3          DRIVAS, Dimitrios  Athens   Aquatics
# 3          Medal No 4         MALOKINIS, Ioannis  Athens   Aquatics
# 4          Medal No 5         CHASAPIS, Spiridon  Athens   Aquatics
# ...               ...                        ...     ...        ...
# 31160  Medal No 31161         JANIKOWSKI, Damian  London  Wrestling
# 31161  Medal No 31162  REZAEI, Ghasem Gholamreza  London  Wrestling
# 31162  Medal No 31163             TOTROV, Rustam  London  Wrestling
# 31163  Medal No 31164          ALEKSANYAN, Artur  London  Wrestling
# 31164  Medal No 31165             LIDBERG, Jimmy  London  Wrestling
#
#                 Discipline Country Gender                       Event   Medal
# ...
